# %% [markdown]
# # Capilano University
# ## Computing and Data Science
# ### Interview questions

# %% [markdown]
# ### Question 1:
# This code is from a 1st year student’s lab submission in COMP115: Computational Thinking;
# It computes some basic metrics on a DNA sequence encoded as an arbitrary string of base letters, "GCAT"
# It passes all tests, but the student asks how they can improve the code.
# How would you advise them?

# %%
def is_valid_seq(seq):
    """
    Return True iff the given string sequence is valid.
    
    valid sequences are made up of triplets of base letters (G,C,A,T)
    """
    for letter in seq:
        if letter == 'G':
            pass
        elif letter == 'C':
            pass
        elif letter == 'A':
            pass
        elif letter == 'T':
            pass
        else:
            return False
    length = 0
    for letter in seq:
        length = length + 1
        if length == 3:
            length = 0
    if length == 0:
        return True
    else:
        return False

# Unit Tests
assert is_valid_seq('GCTACGGAGCTT') == True
assert is_valid_seq('GCTACGGAGCT') == False  # not div. by 3
assert is_valid_seq('CATHATRATTAP') == False  # contains non-bases


def extract_codons(seq):
    """ 
    Return a list of codons from the given sequence of bases (G, C, A, T)
    
    a codon is a triplet of base letters, e.g., CGA or TCT
    """
    l = []
    i = 0
    while i < len(seq):
        l1 = seq[i]
        i = i+1
        l2 = seq[i]
        i = i+1
        l3 = seq[i]
        i = i+1
        l.append(l1 + l2 + l3)

    return l

# Unit Tests
assert extract_codons('ATG') == ['ATG',]
assert extract_codons('AAACCCGGGTTT') == ['AAA', 'CCC', 'GGG', 'TTT']
assert extract_codons('GCTACGGAGCTT') == ['GCT', 'ACG', 'GAG', 'CTT']

print("All tests passed!")
# Out:
# All tests passed!

# %% [markdown]
# ### Question 2:
#
# This question comes from a unit on graph analysis in our 2nd year Intro. to Computational Science.
#
# Consider a random, undirected graph with $n$ nodes connected with probability $p$:

# %%
import random
import networkx as nx

random_graph = nx.erdos_renyi_graph(n=10, p=0.3)
nx.draw_circular(random_graph)

# %% [markdown]
# The following `is_connected(graph)` algorithm determines if an undirected graph is `connected`.
#
# What are some of the **core CS concepts** that would be important to discuss with students about this algorithm?

# %%
def is_connected(graph):
    """ Return True if the graph is connected, False otherwise. """
    start = next(iter(graph))
    reachable = reachable_nodes(graph, start)
    return len(reachable) == len(graph)

def reachable_nodes(graph, start):
    """ return the set of nodes that are reachable from the given start node"""
    seen = set()
    stack = [start]
    while stack:
        node = stack.pop()
        if node not in seen:
            seen.add(node)
            stack.extend(graph.neighbors(node))
    return seen

'Connected' if is_connected(random_graph) else 'Not Connected'
# Out:
# 'Connected'
